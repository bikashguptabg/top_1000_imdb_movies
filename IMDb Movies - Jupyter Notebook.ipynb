# %% [markdown]
# # IMDB Dataset Analysis of Top 1000 Movies and TV Shows
# ---
# ## Steps Involved in this Project
#
# - **Problem Statement:** Define a clear research question.
# - **Domain Knowledge & Dataset Overview:** Understand the movie industry and key dataset columns.
# - **Data Import:** Load the dataset from a CSV file.
# - **Data Access:** Review the dataset manually and programmatically.
# - **Data Cleaning:** Address missing values, duplicates, and anomalies using **Define - Code - Test**.
# - **Feature Engineering:** Optimize columns like **Certificate** and **Genre**.
# - **Exploratory Data Analysis (EDA):** Conduct univariate and bivariate analysis.
# - **Data Visualization:** Use **Seaborn** and **Matplotlib** for impactful visuals.
# - **Correlation Analysis:** Investigate key variable relationships.
# - **Categorical Analysis:** Analyze data by **Certificate Category**, **Genre**, and **Director**.
# - **Conclusion:** Summarize findings.
#
# ---
# ## Problem Statement
# We are an entertainment critic company called **'Kritics'** aiming to publish insightful facts about the most famous movies worldwide. Various stakeholders can utilize this dataset for different purposes:
#
# - **'General public**': The data helps movie enthusiasts discover movies that match their preferences.
# - **'Directors, producers, and other industry professionals**': The insights provide an understanding of how factors such as a movie's runtime, certificate category, and other variables predict its success, particularly in terms of IMDB rating and gross revenue.
# - The key question guiding this project is:
# How can a movie's runtime, certificate category, and other attributes influence its success?
#
# ## Dataset Summary
# The IMDB Top 1000 Movies Dataset is a comprehensive collection of information about the top 1000 highest-rated movies and TV shows as ranked by IMDb users between the period of these 100 years (1920-2020). This dataset contains 16 key attributes, including the title, release year, genre, runtime, and IMDB rating of each film. It also includes details like the director, leading stars, number of votes, and gross earnings. By analyzing this dataset, we can explore various trends in the film industry, such as popular genres, top-rated directors, and the correlation between ratings and revenue.
#
# ## Column Description in the IMDB Dataset
#
# **1. Poster_Link**: The URL link to the movie or TV show's poster image, useful for visual representation.
#
# **2. Series_Title**: The name or title of the movie or TV show.
#
# **3. Released_Year**: The year in which the movie was released or the TV show first aired.
#
# **4. Certificate**: The age rating (e.g., PG, R), indicating the appropriate audience for the content.
# - **U:** Suitable for all ages.
# - **A:** Adults (18+), contains strong language/violence.
# - **UA:** 12+, parental guidance for younger viewers.
# - **R:** 17+, adult content.
# - **PG-13:** 13+, may not be suitable for children.
# - **PG:** Parental guidance suggested, suitable for all.
# - **Passed/Approved:** General audiences, old terms.
# - **G:** Suitable for all ages.
# - **TV-PG:** Parental guidance advised.
# - **GP:** Early term, like PG.
# - **TV-14:** Ages 14+.
# - **16:** 16+, common in Europe.
# - **TV-MA:** 17+, mature content.
# - **Unrated:** Not submitted for rating.
# - **U/A:** Same as UA, used in some regions.
#
# **5. Runtime**: The total duration of the movie or the average duration of an episode, typically measured in minutes.
#
# **6. Genre**: The category or type of the movie or TV show (e.g., Action, Drama, Comedy).
#
# **7. IMDB_Rating**: The rating given by IMDb users, representing the audience's perception of the movie or show, typically on a scale of 1 to 10.
#
# **8. Overview**: A brief synopsis or summary of the movie or TV show’s plot.
#
# **9. Meta_score**: A critic-based score, often aggregated from major film reviews. It reflects professional opinion and ranges from 28 to 100 in this dataset.
#
# **10. Director**: The name of the director who directed the movie or TV show.
#
# **11. Star1**: The lead actor or actress of the movie or TV show.
#
# **12. Star2**: The second main actor or actress.
#
# **13. Star3**: The third main actor or actress.
#
# **14. Star4**: The fourth main actor or actress.
#
# **15. No_of_Votes**: The total number of votes received by the movie or TV show on IMDb, indicating its popularity.
#
# **16. Gross**: The total gross earnings of the movie or TV show, representing its financial success. Note that these figures are only for the USA and Canada, not worldwide earnings.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Data Assessing

# %% [markdown]
# ---

# %% [markdown]
# ## Manual Data Assessment

# %%
#Importing all important libraries required for Exploratory Data Analysis (EDaA)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv(r"C:\Users\bikas\OneDrive\Documents\BA\Final Projects\IMDB Top 1000 Movies\imdb_top_1000.csv")

# %%
movies.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes         Gross
# 0  William Sadler      2343110   2,83,41,469
# ...

# %%
# It's good to have a look at the data manually to get an understanding and point any errors.
# Exporting files for manual assesment in MS Excel as it has better readability and scrolling options.
# Wrong Code - pd.to_csv(movies)
movies.to_csv("Downloads\\movies_export.csv", index=False) #Setting index=False ensures that the DataFrame index is not included in the export.

# %% [markdown]
# ---

# %% [markdown]
# ## Programmatic Data Assessment

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
columns_with_nans = [col for col in movies.columns if movies[col].hasnans]
#Alternate code: columns_with_nans = [col for col in movies.columns if movies[col].isna().any()]
print(columns_with_nans)
# Out:
# ['Certificate', 'Meta_score', 'Gross']

# %%
# Check for duplicate rows in the 'movies' DataFrame
duplicate_count = movies.duplicated().sum()  # Count the total number of duplicated rows

# Print the total number of duplicate rows found
print(f"Number of duplicate rows overall: {duplicate_count}")
# Out:
# Number of duplicate rows overall: 0

# %%
# Count the number of duplicate rows in the 'movies' DataFrame
duplicate_count = movies.duplicated().sum()  # Returns the total number of duplicate rows

# Print the result
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
# Loop through each column in the 'movies' DataFrame
for col in movies.columns:
    # Check if the column has any duplicate values
    if movies[col].duplicated().sum() != 0:
        print(col)  # Print the name of the column with duplicates

# Additional check for duplicates specifically in the 'Series_Title' column
if movies['Series_Title'].duplicated().sum() != 0:
    print("Series_Title has duplicates.")
# Out:
# Series_Title
# Released_Year
# Certificate
# Runtime
# Genre
# IMDB_Rating
# Meta_score
# Director
# Star1
# Star2
# Star3
# Star4
# No_of_Votes
# Gross
# Series_Title has duplicates.

# %%
#Checking if the value is correct or not - Series_Title
movies[movies['Series_Title'].duplicated(keep = False)] #keep = False is used to see all the duplicated values.
# After doing some research on Google, it was found that both the movies are separate movies with the same name. Hence, no cleaning is required.
# Out:
#                                            Poster_Link Series_Title  \
# 87   https://m.media-amazon.com/images/M/MV5BYmY3Mz...     Drishyam
# 136  https://m.media-amazon.com/images/M/MV5BYmJhZm...     Drishyam
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 87           2013           U  160 min  Crime, Drama, Thriller          8.3
# 136          2015          UA  163 min   Crime, Drama, Mystery          8.2
#
#                                               Overview  Meta_score  \
# 87   A man goes to extreme lengths to save his fami...         NaN
# 136  Desperate measures are taken by a man who trie...         NaN
#
#             Director       Star1         Star2         Star3         Star4  \
# 87     Jeethu Joseph    Mohanlal         Meena  Asha Sharath        Ansiba
# 136  Nishikant Kamat  Ajay Devgn  Shriya Saran          Tabu  Rajat Kapoor
#
#      No_of_Votes     Gross
# 87         30722       NaN
# 136        70367  7,39,478

# %%
# Count the occurrences of each unique value in the 'Certificate' column
movies['Certificate'].value_counts()
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: count, dtype: int64

# %%
# Suggestions categorized by age suitability and guidance requirements:
# 1. General Audiences (All Ages): U, G, Approved, Passed
# 2. Parental Guidance Suggested: UA, PG, TV-PG, GP, PG-13
# 3. Restricted or Mature Audiences: A, R, TV-14, TV-MA, 16, Unrated

# %%
# Generate descriptive statistics for the DataFrame
movies.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %% [markdown]
# # After above analysis on numerical columns, the minimum values of Meta_score was found ot be very low and further analysis was required.
# movies[(movies['Meta_score'] > 25) & (movies['Meta_score'] < 35)]
# # After running this code, it is clear that there are other values as well close to the minimum value and it does not look like an inccurate data.
# # Hence, no cleaning is required.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ---

# %% [markdown]
# # Issues Found in the Dataset
#
# #### Dirty Data
# 1. **Runtime** : Format is written as "xx mins", but it should be convert to only XX and that too in integer format. `validity issue` [CHECK]
# 2. **Released_Year** : It has a value "PG" which is a string value. `validity issue` [CHECK]
# 3. **Changing the dtypes** : Release_Year (int32), Runtime (int16), Genre (category), Metascore (int8), Gross (int64) `validity issue` [CHECK]
# 4.  - **['Certificate', 'Meta_score']** has missing values `completion issue` [CHECK],
#     - **Gross** column has missing values but it is because of wrong dtype. `validity issue` [CHECK]
# 5. **Certificate** : U/A and UA has to be combined. `consistency issue` [CHECK]
# 6. **Strip** all the textual columns as it is a good practice to remove the trailing spaces from both the sides. `consistency issue` [CHECK]
# #### Messy Data
# - no data recorded
# ### Feature Engineering
# 7. **Bucketing of `Certicate` column** :
#     - **For General Audiences (All Ages)**: U, G, Approved, Passed
#     - **Parental Guidance Suggested**: UA / U/A, PG, TV-PG, GP, PG-13
#     - **Restricted or Mature Audiences**: A, R, TV-14, TV-MA, 16, Unrated.
#
# These categories would help classify the content based on how suitable it is for different age groups.
# #### Additonal Notes
# - **Series_Title** : It has many special characters, it can create a problem while importing data in MySQL. This needs to be check when importing data in MySQL, no data cleaing required as of now for analysis in Python.

# %%
# Creating a copy of the original data before any data cleaning
movies_original = movies.copy()

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 1
# - Runtime : Format is written as "xx mins".
# #### Define
# - It should be converted to only XX format for proper analysis.

# %%
# Code
movies['Runtime'] = movies['Runtime'].str.split(" ").str.get(0)

# %%
# Test
movies['Runtime']
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime, Length: 1000, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 2
# - Released_Year : It has a value "PG" which is a string value. validity issue
# #### Define
# - After doing some research, it is found that 'Apollo 13' movie is the value with Released_Year = PG. By checking on the internet, it was found that the movie was released in the year 1995. Hence, 'PG' should be replaced with 1995.

# %%
# Code
movies[movies['Released_Year'] == "PG"]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate Runtime                      Genre  IMDB_Rating  \
# 966            PG           U     140  Adventure, Drama, History          7.6
#
#                                               Overview  Meta_score  \
# 966  NASA must devise a strategy to return Apollo 1...        77.0
#
#        Director      Star1        Star2        Star3        Star4  \
# 966  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes         Gross
# 966       269197  17,38,37,933

# %%
# Code
movies['Released_Year'] = movies['Released_Year'].replace({"PG": 1995})

# %%
# Test
movies[movies['Released_Year'] == "PG"]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 3
# - Incorrect dtypes for Release_Year, Runtime, Genre, Meta_score and Gross
# #### Define
# - **Changing the dtypes** : Released_Year (int32), Runtime (int16), Genre (category), Meta_score (int8), Gross (int64)
# - For Gross column, there are commas in between, so it needs to be removed and then converted to the desired dtype (int64)

# %%
# Code
movies['Released_Year'] = movies['Released_Year'].astype('category')
movies['Runtime'] = movies['Runtime'].astype(np.int16)
movies['Genre'] = movies['Genre'].astype('category')
movies['Meta_score'] = movies['Meta_score'].astype(np.int8)

movies['Gross'] = movies['Gross'].str.replace(',', '')
# This line replaces commas (,) in the 'Gross' column with empty strings (''). This is necessary because commas are typically used in large numbers.
movies['Gross'] = pd.to_numeric(movies['Gross'], errors='coerce').astype('Int64')
# This converts the 'Gross' column to a numeric type using pd.to_numeric(). 
# If there are any invalid values that can't be converted, it sets them as NaN (due to errors='coerce').
# Finally, .astype('Int64') converts the column to an integer type, but it uses Int64, which allows for missing values (NaN), unlike regular int64.

# %%
# Test
# Wrong code: movies['Released_Year','Runtime','Genre','Meta_score'].info() - because .info() is meant to be called on a DataFrame, 
# and not on a Series or list of columns. A subset of the DataFrame needs to be created
movies[['Released_Year', 'Runtime', 'Genre', 'Meta_score','Gross']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Released_Year  1000 non-null   category
#  1   Runtime        1000 non-null   int16
#  2   Genre          1000 non-null   category
#  3   Meta_score     1000 non-null   int8
#  4   Gross          831 non-null    Int64
# dtypes: Int64(1), category(2), int16(1), int8(1)
# memory usage: 29.3 KB

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 4
# - ['Certificate', 'Meta_score', 'Gross'] has missing values completion issue
# #### Define
# - Replace all the null values in `Certificate` column with 'Unknown' as there are 101 null values which contributes to 10.1% of the total rows.
# - Replace all the null values in `Meta_score` column with the mean of the Meta_score column as there are 157 null values which contributes to 15.7% of the total rows and removing them might remove many important data from other columns as well.
# - Replace all the null values in `Gross` column with the mean of the Gross column as there are 169 null values which contributes to 16.9% of the total rows and removing them might remove many important data from other columns as well.

# %%
# Code
movies['Certificate'].fillna('Unknown', inplace = True)
movies['Meta_score'].fillna(movies['Meta_score'].mean(), inplace = True)

# Wrong code - movies['Gross'].fillna(movies['Gross'].mean()) - As the mean value is in float dtype and the column supports only int64.
movies['Gross'] = movies['Gross'].fillna(round(movies['Gross'].mean()))

# %%
# Test
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   category
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   int16
#  5   Genre          1000 non-null   category
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   int8
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          1000 non-null   Int64
# ...

# %%
# Test
print(movies['Certificate'].isnull().sum())
print(movies['Meta_score'].isnull().sum())
print(movies['Gross'].isnull().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 5
# - Certificate : U/A and UA is separately present.
# #### Define
# - Replacing UA with U/A.

# %%
# Code 
movies['Certificate'] = movies['Certificate'].str.replace('UA', 'U/A')

# %%
# Test
print((movies['Certificate'] == 'UA').sum())
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 6
# - **Strip** all the textual columns as it is a good practice to remove the trailing spaces from both the sides. `consistency issue`
#
# #### Define
# - Using the Strip method for do this for each textual columns.

# %%
[col for col in movies.columns if movies[col].dtype == 'object']
# Out:
# ['Poster_Link',
#  'Series_Title',
#  'Certificate',
#  'Overview',
#  'Director',
#  'Star1',
#  'Star2',
#  'Star3',
#  'Star4']

# %%
# Code & Test
for col in movies.columns:
    # Check if the column is of type 'object' (which represents strings in pandas)
    if movies[col].dtype == 'object':
        # Apply strip() to the entire column
        movies[col] = movies[col].str.strip()
print("Strip operation successful for all the textual columns in the movies dataset.")
# Out:
# Strip operation successful for all the textual columns in the movies dataset.

# %% [markdown]
# ### Problem 7
# - **Bucketing of `Certicate` columns** as there are many similar types of certifications that can be grouped.
# #### Define
# - Classification under these categories with a new column named 'Certificate_Category':
#     - **For General Audiences (All Ages)**: U, G, Approved, Passed
#     - **Parental Guidance Suggested**: UA / U/A, PG, TV-PG, GP, PG-13
#     - **Restricted or Mature Audiences**: A, R, TV-14, TV-MA, 16, Unrated.

# %%
# Code
# Creating a function to check logically how the values should be bucketed
def check_certificate_category(certificate):
    if certificate in ['U', 'G', 'Approved', 'Passed']:
        return "For General Audiences"
    elif certificate in ['UA', 'U/A', 'PG', 'TV-PG', 'GP', 'PG-13']:
        return "Parental Guidance Suggested"
    elif certificate in ['A', 'R', 'TV-14', 'TV-MA', '16', 'Unrated']:
        return "For Mature Audiences"
    else:
        return "Not Available"

# Creating a new column Certificate_Category by applying the function to the 'Certificate' column
movies['Certificate_Category'] = movies['Certificate'].apply(check_certificate_category)

# %%
# Test
movies['Certificate_Category']
# Out:
# 0             For Mature Audiences
# 1             For Mature Audiences
# 2      Parental Guidance Suggested
# 3             For Mature Audiences
# 4            For General Audiences
#                   ...
# 995           For Mature Audiences
# 996          For General Audiences
# 997          For General Audiences
# 998                  Not Available
# 999                  Not Available
# Name: Certificate_Category, Length: 1000, dtype: object

# %%
movies.sample(2)
# Out:
#                                            Poster_Link          Series_Title  \
# 747  https://m.media-amazon.com/images/M/MV5BMTYwMz...   Beasts of No Nation
# 985  https://m.media-amazon.com/images/M/MV5BNDQ3Mz...  Escape from Alcatraz
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 747          2015     Unknown      137                Drama, War          7.7
# 985          1979           A      112  Action, Biography, Crime          7.6
#
#                                               Overview  Meta_score  \
# 747  A drama based on the experiences of Agu, a chi...          79
# 985  Alcatraz is the most secure prison of its time...          76
#
#                Director           Star1             Star2             Star3  \
# 747  Cary Joji Fukunaga   Abraham Attah  Emmanuel Affadzi  Ricky Adelayitor
# 985          Don Siegel  Clint Eastwood  Patrick McGoohan   Roberts Blossom
#
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ---

# %%
# Numerical Columns in the dataset:
[co for co in movies.columns if movies[co].dtype != 'object' and movies[co].dtype != 'category']
# Out:
# ['Runtime', 'IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross']

# %%
# Categorical Columns:
[co for co in movies.columns if movies[co].dtype == 'object' or movies[co].dtype == 'category']
# Out:
# ['Poster_Link',
#  'Series_Title',
#  'Released_Year',
#  'Certificate',
#  'Genre',
#  'Overview',
#  'Director',
#  'Star1',
#  'Star2',
#  'Star3',
#  'Star4',
#  'Certificate_Category']

# %% [markdown]
# ## Univariate Analysis
# ---

# %% [markdown]
# ### Runtime
# - The data is almost normally distributed.
# - The maximum Runtime is 321 mins (5 hrs 21 mins) which is of 'Gangs of Wasseypur' movie. This is because the movie was released in 2 parts within a span of 2 months in the year 2012. So it is actually the summation of runtimes of the two parts which is summed up as one in this dataset.
# - Most of the movies ranges from 100-140 mins.
# - There are outliers which are termed above around 200. But all of the data is accurate and no data filtering is required.

# %%
movies['Runtime'].describe()
# Out:
# count    1000.000000
# mean      122.891000
# std        28.093671
# min        45.000000
# 25%       103.000000
# 50%       119.000000
# 75%       137.000000
# max       321.000000
# Name: Runtime, dtype: float64

# %%
movies[movies['Runtime'] > 250] # Better than movies[movies['Runtime'] == 321] as it only will fetch the max value of 321 and not other higher end data.
# Out:
#                                            Poster_Link        Series_Title  \
# 140  https://m.media-amazon.com/images/M/MV5BMTc5Nj...  Gangs of Wasseypur
#
#     Released_Year Certificate  Runtime                  Genre  IMDB_Rating  \
# 140          2012           A      321  Action, Comedy, Crime          8.2
#
#                                               Overview  Meta_score  \
# 140  A clash between Sultan and Shahid Khan leads t...          89
#
#            Director           Star1         Star2                Star3  \
# 140  Anurag Kashyap  Manoj Bajpayee  Richa Chadha  Nawazuddin Siddiqui
#
#                 Star4  No_of_Votes     Gross  Certificate_Category
# 140  Tigmanshu Dhulia        82365  68034751  For Mature Audiences

# %%
# Set the style for the plot
plt.style.use('fivethirtyeight')

# Create a figure and its desired size for the histogram
plt.figure(figsize=(10, 3)) # first parameter is for breadth and the second one is for length of the figure.

# Create a histogram of the 'Runtime' column
plt.hist(movies['Runtime'], bins=30, edgecolor='black', color='gold')
# sns.histplot(movies['Runtime'], bins=30, edgecolor='black', color='gold')

# Label the x-axis and y-axis
plt.xlabel('Runtime')
plt.ylabel('Frequency')

# Set the title of the plot
plt.title('Distribution of Movie Runtimes')

# Add a text annotation to the plot
plt.text(115, 10, 'Most Movies', fontsize=10, ha='center') # ha = horizontal alignment

# Show the plot
plt.show()

# %%
# Box plot to check for outliers
plt.figure(figsize=(2, 4))  # Adjust figure size as needed
sns.boxplot(y=movies['Runtime'], color='orange')  # Box plot with Seaborn
# sns.boxplot(data=movies, y='Runtime', color='orange') 
plt.xlabel('Runtime')
plt.title('Box Plot of Movie Runtimes')
plt.show()

# %%
movies[movies['Runtime'] > 200]
# Out:
#                                            Poster_Link  \
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 31   https://m.media-amazon.com/images/M/MV5BOWE4ZD...
# 71   https://m.media-amazon.com/images/M/MV5BMGFkNW...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 140  https://m.media-amazon.com/images/M/MV5BMTc5Nj...
# 156  https://m.media-amazon.com/images/M/MV5BYzExOT...
# 177  https://m.media-amazon.com/images/M/MV5BOGZiM2...
# 247  https://m.media-amazon.com/images/M/MV5BNDYxNW...
# 290  https://m.media-amazon.com/images/M/MV5BNjM2Mj...
# 300  https://m.media-amazon.com/images/M/MV5BNjgxY2...
# 314  https://m.media-amazon.com/images/M/MV5BYjUyZW...
# 484  https://m.media-amazon.com/images/M/MV5BMGUyM2...
# 552  https://m.media-amazon.com/images/M/MV5BODcxYj...
# 812  https://m.media-amazon.com/images/M/MV5BM2U5OW...
# 820  https://m.media-amazon.com/images/M/MV5BZDkzOT...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### IMDB_Rating
# - The data is right-shekwed and most of the data is in the range 7.5 - 8.3 IMDB ratings.
# - Outliers are valid.

# %%
movies['IMDB_Rating'].describe()
# Out:
# count    1000.000000
# mean        7.949300
# std         0.275491
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: IMDB_Rating, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore') # Some warnings were occuring along with the graph, used this code to disable it.

plt.figure(figsize=(5, 2))
sns.histplot(movies['IMDB_Rating'], kde=True, color = 'Gold', alpha = .75) # alpha = for transparency
plt.xlabel('IMDB Rating')
plt.title('Distribution of IMDB Ratings')
plt.show()

# %%
# Box plot to check for outliers
plt.figure(figsize=(2, 4)) 
sns.boxplot(y=movies['IMDB_Rating'], color='orange')  # Box plot with Seaborn
plt.xlabel('IMDB_Rating')
plt.title('Box Plot of Movie IMDB_Rating')
plt.show()

# %%
movies[movies['IMDB_Rating'] >= 8.7]
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 15  https://m.media-amazon.com/images/M/MV5BY2NkZj...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Meta_score
# - Data is left skewed, and most of the data ranges from 70-90 metascore.
# - Outliers are valid.

# %%
movies['Meta_score'].describe()
# Out:
# count    1000.000000
# mean       77.819000
# std        11.367562
# min        28.000000
# 25%        72.000000
# 50%        77.000000
# 75%        85.250000
# max       100.000000
# Name: Meta_score, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore') # Some warnings were occuring along with the graph, used this code to disable it.

plt.figure(figsize=(5, 2))
sns.histplot(movies['Meta_score'], kde=True, color = 'Gold', alpha = .75, bins =10)
plt.xlabel('Metascore')
plt.title('Distribution of Metascore')
plt.show()

# %%
plt.figure(figsize=(2, 4))  # Adjust figure size as needed
sns.boxplot(y=movies['Meta_score'], color='orange')  # Box plot with Seaborn
plt.xlabel('Meta_score')
plt.title('Box Plot of Movie Metascore')
plt.show()

# %%
movies[movies['Meta_score'] <= 52]
# Out:
#                                            Poster_Link  \
# 272  https://m.media-amazon.com/images/M/MV5BZDhlZT...
# 342  https://m.media-amazon.com/images/M/MV5BMTA2ND...
# 352  https://m.media-amazon.com/images/M/MV5BMTUyMT...
# 356  https://m.media-amazon.com/images/M/MV5BYmI1OD...
# 397  https://m.media-amazon.com/images/M/MV5BNzZmMj...
# 569  https://m.media-amazon.com/images/M/MV5BMTlkMm...
# 597  https://m.media-amazon.com/images/M/MV5BMTQ4Mz...
# 615  https://m.media-amazon.com/images/M/MV5BMTM4Nz...
# 630  https://m.media-amazon.com/images/M/MV5BMTU4NT...
# 644  https://m.media-amazon.com/images/M/MV5BYThkMz...
# 648  https://m.media-amazon.com/images/M/MV5BYzVmMT...
# 659  https://m.media-amazon.com/images/M/MV5BODRkYz...
# 677  https://m.media-amazon.com/images/M/MV5BY2QwYm...
# 735  https://m.media-amazon.com/images/M/MV5BMTgwNT...
# 742  https://m.media-amazon.com/images/M/MV5BMTM3Nz...
# 760  https://m.media-amazon.com/images/M/MV5BMTU2Nj...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### No_of_Votes
# - The frequency of this column's value follow the geometric distribution.
# - Outliers are valid.

# %%
movies['No_of_Votes'].describe()
# Out:
# count    1.000000e+03
# mean     2.736929e+05
# std      3.273727e+05
# min      2.508800e+04
# 25%      5.552625e+04
# 50%      1.385485e+05
# 75%      3.741612e+05
# max      2.343110e+06
# Name: No_of_Votes, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore') # Some warnings were occuring along with the graph, used this code to disable it.

plt.figure(figsize=(5, 2))
sns.histplot(movies['No_of_Votes'] / 1000, kde=True, color='Gold', alpha=0.75, bins=10)
plt.xlabel('No of Votes (in thousands)')
# Customize x-axis ticks to add "K"
ticks = plt.xticks()[0]  # Get current ticks
plt.xticks(ticks, [f"{int(tick)}K" for tick in ticks])  # Add "K" suffix to each tick using f strings.
plt.title('Distribution of Votes')
plt.show()

# %%
# Box plot to check for outliers
plt.figure(figsize=(2, 4))  # Adjust figure size as needed
sns.boxplot(y=movies['No_of_Votes'], color='orange')  # Box plot with Seaborn

plt.ylabel('No of Votes')  # Set the y-axis label
plt.title('Box Plot of No of Votes')

# Get current ticks and format them
ticks = plt.yticks()[0]  # Get current ticks from y-axis
plt.yticks(ticks, [f"{int(tick/1000)}K" for tick in ticks])  # Add "K" suffix to each tick

plt.show()

# %%
movies[movies['No_of_Votes'] > 850000]
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# ..                                                 ...
# 376  https://m.media-amazon.com/images/M/MV5BNGYyZG...
# 477  https://m.media-amazon.com/images/M/MV5BOTAzOD...
# 502  https://m.media-amazon.com/images/M/MV5BMTczNT...
# 623  https://m.media-amazon.com/images/M/MV5BMTYwOT...
# 652  https://m.media-amazon.com/images/M/MV5BMDdmZG...
#
#                                           Series_Title Released_Year  \
# 0                             The Shawshank Redemption          1994
# 1                                        The Godfather          1972
# 2                                      The Dark Knight          2008
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Gross
# - Follows Geometric dsitribution
# - Cross-checked the values from here and IMDb website for other movies. It was found that the earnings shown are not world-wide earnings. It is the earnings from the countries USA and Canada only. Hence, it's safe to assume that the data in this column is accurate even if there is such low mimimum values. Also, some of the values has been cross-checked with the IMDb website itself from Google.
# - Outliers are valid.

# %%
movies['Gross'].describe()
# Out:
# count              1000.0
# mean         68034750.895
# std      100037078.931419
# min                1305.0
# 25%            5012919.25
# 50%            42389449.0
# 75%            68034751.0
# max           936662225.0
# Name: Gross, dtype: Float64

# %%
# Checking the minimum value
movies[movies['Gross'] == 1305]
# Out:
#                                            Poster_Link Series_Title  \
# 630  https://m.media-amazon.com/images/M/MV5BMTU4NT...  Adams æbler
#
#     Released_Year Certificate  Runtime                 Genre  IMDB_Rating  \
# 630          2005           R       94  Comedy, Crime, Drama          7.8
#
#                                               Overview  Meta_score  \
# 630  A neo-nazi sentenced to community service at a...          51
#
#                  Director           Star1           Star2        Star3  \
# 630  Anders Thomas Jensen  Ulrich Thomsen  Mads Mikkelsen  Nicolas Bro
#
#              Star4  No_of_Votes  Gross  Certificate_Category
# 630  Paprika Steen        45717   1305  For Mature Audiences

# %%
# Further analysis: Cross-checked the other values from here for the gross column and IMDb website for other movies.
movies[movies['Gross'] < 50000]
# Out:
#                                            Poster_Link  \
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# 125  https://m.media-amazon.com/images/M/MV5BODA4OD...
# 141  https://m.media-amazon.com/images/M/MV5BNzgxMz...
# 142  https://m.media-amazon.com/images/M/MV5BNTgwOD...
# 187  https://m.media-amazon.com/images/M/MV5BOWIwOD...
# 190  https://m.media-amazon.com/images/M/MV5BMTY2MT...
# 239  https://m.media-amazon.com/images/M/MV5BOGViNT...
# 287  https://m.media-amazon.com/images/M/MV5BMWFjZj...
# 317  https://m.media-amazon.com/images/M/MV5BNjBjND...
# 350  https://m.media-amazon.com/images/M/MV5BYjU1Nj...
# 356  https://m.media-amazon.com/images/M/MV5BYmI1OD...
# 390  https://m.media-amazon.com/images/M/MV5BMTk2Mj...
# 605  https://m.media-amazon.com/images/M/MV5BMTgzMT...
# 624  https://m.media-amazon.com/images/M/MV5BMTg4OD...
# 630  https://m.media-amazon.com/images/M/MV5BMTU4NT...
# 636  https://m.media-amazon.com/images/M/MV5BMzYwOD...
# ...

# %%
plt.figure(figsize=(6, 2)) 
sns.histplot(movies['Gross'], bins=20, color='Gold')
plt.xlabel('Gross Earnings')
plt.ylabel('Count of Movies')
plt.title('Distribution of Gross Earnings')
plt.show()

# %%
plt.figure(figsize=(2, 4)) 
sns.boxplot(movies['Gross'], color='Gold')
plt.ylabel('Gross Earnings')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Series_Title
# - 2 values for Drishyam - After some online research, it is found that both the movies are different. Bollywood version is the copied version of Telugu version.

# %%
movies['Series_Title'].value_counts()
# Out:
# Series_Title
# Drishyam                    2
# The Shawshank Redemption    1
# Awakenings                  1
# Tombstone                   1
# The Sandlot                 1
#                            ..
# Guardians of the Galaxy     1
# Blade Runner 2049           1
# Her                         1
# Bohemian Rhapsody           1
# The 39 Steps                1
# Name: count, Length: 999, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Released_Year
#
# - Most of the movies in the dataset are new releases from recent years. The bar graph shows values skewed to the right, indicating left-skewed (or negatively skewed) data.
# - **Top 5 Years with the Highest Number of Movies:**
#     - **2014:** 32
#     - **2004:** 31
#     - **2009:** 29
#     - **2016:** 28
#     - **2013:** 28

# %%
# Top 5 Years that released movies in the category of Top 1000 Movies
viz0 = movies['Released_Year'].value_counts().head(5)
viz0
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2016    28
# 2013    28
# Name: count, dtype: int64

# %%
viz1 = movies['Released_Year'].value_counts().sort_index()
viz1
# Out:
# Released_Year
# 1920     1
# 1921     1
# 1922     1
# 1924     1
# 1925     2
#         ..
# 2016    28
# 2017    22
# 2018    19
# 2019    23
# 2020     6
# Name: count, Length: 99, dtype: int64

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=viz1.index, y=viz1.values)
plt.ylabel('Count of Movies Released')
plt.xlabel('Released Year')
plt.title('Count of Movies Released by Year')

# Set x ticks to vertical and adjust font size using Axes
ax = plt.gca()  # Get the current Axes instance
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=10)  # Adjust rotation and fontsize

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Certificate Category
# - Of the 4 types of certification categories, interestingly 'Mature Audience' category tops the list with 34.7% or 347 movies of the total 1000 movies.

# %%
movies['Certificate_Category'].value_counts()
# Out:
# Certificate_Category
# For Mature Audiences           347
# For General Audiences          291
# Parental Guidance Suggested    261
# Not Available                  101
# Name: count, dtype: int64

# %%
# Create a pie chart
plt.figure(figsize=(3, 3))  # Set the figure size
plt.pie(certificate_counts, 
        labels=certificate_counts.index,  # Category labels
        autopct='%1.1f%%',  # Format for displaying percentages
        startangle=140,  # Start angle for the pie chart
        colors=sns.color_palette('Set2'))  # Use a color palette

plt.title('Certificate Category Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Director
# - Top 5 directors

# %%
top_directors = movies['Director'].value_counts().head(5)
top_directors
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
# Name: count, dtype: int64

# %%
sns.barplot(x=top_directors.index, y=top_directors.values)

plt.xlabel('Directors')
plt.ylabel('Number of Movies')
plt.title('Top Directors by Number of Movies')

ax1 = plt.gca()  # Get the current Axes instance
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)  # Adjust rotation and fontsize

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Star1 + Star2 + Star3 + Star4
# - Top Stars overall
# - Top 5 Leading Stars

# %%
# Concatenating all 'Star' columns into a single series
stars = pd.concat([movies['Star1'], movies['Star2'], movies['Star3'], movies['Star4']], ignore_index=True)
stars.size
# Out:
# 4000

# %%
stars_count = stars.value_counts()
filtered_stars = stars_count[stars_count > 7]
filtered_stars
# Out:
# Robert De Niro        17
# Tom Hanks             14
# Al Pacino             13
# Clint Eastwood        12
# Brad Pitt             12
# Leonardo DiCaprio     11
# Matt Damon            11
# Christian Bale        11
# James Stewart         10
# Ethan Hawke            9
# Scarlett Johansson     9
# Michael Caine          9
# Johnny Depp            9
# Humphrey Bogart        9
# Denzel Washington      9
# Aamir Khan             8
# Harrison Ford          8
# Name: count, dtype: int64

# %%
# Plot a horizontal bar chart
sns.barplot(x=filtered_stars.values, y=filtered_stars.index)
plt.xlabel('Count')
plt.ylabel('Stars')
plt.title('Top Stars with Most Number of Movies')
# Display the plot
plt.show()

# %%
# First, get the counts of each star in the 'Star1' column
plt.figure(figsize=(6, 4))
star_counts = movies['Star1'].value_counts().head(10)

# Plot a horizontal bar chart
sns.barplot(x=star_counts.values, y=star_counts.index)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Stars')
plt.title('Top Leading Star with Most Number of Movies')

# Display the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Genre
# - 28.5% of all the genres are of the Drama genre which is the top most genre category.

# %%
# Process the 'Genre' column to create a new series of individual genres
new_genre_series = (
    movies['Genre']               # Select the 'Genre' column from the DataFrame
    .str.split(', ')              # Split each string in the column into a list of genres using ', ' as the delimiter
    .explode()                    # Flatten the list of genres into individual rows (one genre per row)
    .reset_index(drop=True)       # Reset the index of the resulting Series; drop=True means do not keep the old index
)

# Display the new series
print(new_genre_series)
# Out:
# 0          Drama
# 1          Crime
# 2          Drama
# 3         Action
# 4          Crime
#           ...
# 2536       Drama
# 2537         War
# 2538       Crime
# 2539     Mystery
# 2540    Thriller
# Name: Genre, Length: 2541, dtype: object

# %%
genre_counts = new_genre_series.value_counts()
genre_counts
# Out:
# Genre
# Drama        724
# Comedy       233
# Crime        209
# Adventure    196
# Action       189
# Thriller     137
# Romance      125
# Biography    109
# Mystery       99
# Animation     82
# Sci-Fi        67
# Fantasy       66
# History       56
# Family        56
# War           51
# Music         35
# Horror        32
# Western       20
# Film-Noir     19
# Sport         19
# Musical       17
# Name: count, dtype: int64

# %%
movies.shape[0]
# Out:
# 1000

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot of genre counts
bar_plot = sns.barplot(y=genre_counts.index, x=genre_counts.values)

# Loop through the genre counts and add data labels beside each bar
for index, value in enumerate(genre_counts.values):
    percentage = (value / len(movies)) * 100  # Calculate percentage
    bar_plot.text(value, index, f'{value} ({percentage:.1f}%)', va='center')

# Add title and display the plot
plt.title('Genre Counts')
plt.show()

# %% [markdown]
# ## Bivariate Analysis
# ---

# %% [markdown]
# ### Series_Title vs IMDB_Rating : Top 15

# %%
movies.sort_values(by='IMDB_Rating', ascending=False)[['Series_Title', 'IMDB_Rating']].head(15).reset_index(drop=True).set_index('Series_Title')
# Out:
#                                                    IMDB_Rating
# Series_Title
# The Shawshank Redemption                                   9.3
# The Godfather                                              9.2
# The Dark Knight                                            9.0
# The Godfather: Part II                                     9.0
# 12 Angry Men                                               9.0
# The Lord of the Rings: The Return of the King              8.9
# Pulp Fiction                                               8.9
# Schindler's List                                           8.9
# The Lord of the Rings: The Fellowship of the Ring          8.8
# Forrest Gump                                               8.8
# Il buono, il brutto, il cattivo                            8.8
# Fight Club                                                 8.8
# Inception                                                  8.8
# The Lord of the Rings: The Two Towers                      8.7
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Series_Title with Metascore 100

# %%
movies[movies['Meta_score'] == 100].sort_values(by='Meta_score', ascending=False)[['Series_Title', 'Meta_score']].reset_index(drop=True).set_index('Series_Title')
# Out:
#                         Meta_score
# Series_Title
# The Godfather                  100
# Casablanca                     100
# Rear Window                    100
# Lawrence of Arabia             100
# Vertigo                        100
# Citizen Kane                   100
# Trois couleurs: Rouge          100
# Fanny och Alexander            100
# Il conformista                 100
# Sweet Smell of Success         100
# Boyhood                        100
# Notorious                      100

# %% [markdown]
# ---

# %% [markdown]
# ### Series_Title vs No_of_Votes - Top 15 Most Popular Movies

# %%
top15votes = movies.sort_values(by='No_of_Votes', ascending=False)[['Series_Title', 'No_of_Votes']].head(15).reset_index(drop=True)
top15votes
# Out:
#                                          Series_Title  No_of_Votes
# 0                            The Shawshank Redemption      2343110
# 1                                     The Dark Knight      2303232
# 2                                           Inception      2067042
# 3                                          Fight Club      1854740
# 4                                        Pulp Fiction      1826188
# 5                                        Forrest Gump      1809221
# 6                                          The Matrix      1676426
# 7   The Lord of the Rings: The Fellowship of the Ring      1661481
# 8       The Lord of the Rings: The Return of the King      1642758
# 9                                       The Godfather      1620367
# 10                              The Dark Knight Rises      1516346
# 11                                       Interstellar      1512360
# 12              The Lord of the Rings: The Two Towers      1485555
# ...

# %%
# Create a horizontal bar plot
plt.figure(figsize=(15,5))
sns.barplot(y='Series_Title', x='No_of_Votes', data=top15votes)
# Set titles and labels
plt.title('Top 15 Movies by Votes')
plt.ylabel('Movies')  # Y-axis now represents movies
plt.xlabel('Number of Votes')  # X-axis now represents votes
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Series_Title vs Gross Earnings - Top 15 Most Earning Movies

# %%
top15gross = movies.sort_values(by='Gross', ascending=False)[['Series_Title', 'Gross']].head(15).reset_index(drop=True)
top15gross
# Out:
#                                   Series_Title      Gross
# 0   Star Wars: Episode VII - The Force Awakens  936662225
# 1                            Avengers: Endgame  858373000
# 2                                       Avatar  760507625
# 3                       Avengers: Infinity War  678815482
# 4                                      Titanic  659325379
# 5                                 The Avengers  623279547
# 6                                Incredibles 2  608581744
# 7                              The Dark Knight  534858444
# 8                                    Rogue One  532177324
# 9                        The Dark Knight Rises  448139099
# 10                  E.T. the Extra-Terrestrial  435110554
# 11                                 Toy Story 4  434038008
# 12                               The Lion King  422783777
# 13                                 Toy Story 3  415004880
# 14                  Captain America: Civil War  408084349

# %%
# Create a horizontal bar plot
plt.figure(figsize=(15,5))
sns.barplot(y='Series_Title', x='Gross', data=top15gross)
# Set titles and labels
plt.title('Top 15 Movies by Gross Earnings')
plt.ylabel('Movies')  # Y-axis now represents movies
plt.xlabel('Gross Earnings')  # X-axis now represents votes
plt.show()

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross',
#        'Certificate_Category'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Released_Year vs No_of_Votes

# %%
# Grouping by Released_Year and aggregating No_of_Votes
released_year_votes = movies.groupby('Released_Year')[['No_of_Votes']].sum().reset_index()

# Display the result for No_of_Votes
print(released_year_votes)
# Out:
#    Released_Year  No_of_Votes
# 0           1920        57428
# 1           1921       113314
# 2           1922        88794
# 3           1924        41985
# 4           1925       154107
# ..           ...          ...
# 94          2016      6712011
# 95          2017      5689995
# 96          2018      4170864
# 97          2019      5983576
# 98          2020       504762
#
# [99 rows x 2 columns]

# %%
# Assuming released_year_votes is the DataFrame with No_of_Votes data
plt.figure(figsize=(15,4))

sns.lineplot(data=released_year_votes, x='Released_Year', y='No_of_Votes')

# Add labels and title for No_of_Votes plot
plt.xlabel('Released Year')
plt.ylabel('No of Votes')
plt.title('No of Votes Over the Years')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Released_Year vs Gross

# %%
# Grouping by Released_Year and aggregating Gross
released_year_gross = movies.groupby('Released_Year')[['Gross']].sum().reset_index()

# Display the result for Gross
print(released_year_gross)
# Out:
#    Released_Year       Gross
# 0           1920    68034751
# 1           1921     5450000
# 2           1922    68034751
# 3           1924      977375
# 4           1925     5500970
# ..           ...         ...
# 94          2016  2935731180
# 95          2017  2197382354
# 96          2018  2947931117
# 97          2019  2882985945
# 98          2020   408208506
#
# [99 rows x 2 columns]

# %%
# Assuming released_year_votes is the DataFrame with No_of_Votes data
plt.figure(figsize=(15,4))

sns.lineplot(data=released_year_gross, x='Released_Year', y='Gross')

# Add labels and title for No_of_Votes plot
plt.xlabel('Released Year')
plt.ylabel('Gross')
plt.title('Gross Earnings Over the Years')
plt.show()

# %% [markdown]
# ---
# ### Certificate Category vs No of Votes
# #### Parental Guidance Suggested	& Mature Audience certifcate categories are similar with average number of votes per movies and tops the chart.

# %%
# Create the pivot table and then round the mean values
cc = movies.pivot_table(values='No_of_Votes', 
                         index='Certificate_Category', 
                         aggfunc=np.mean).sort_values('No_of_Votes', ascending=False)

# Round the mean values to 0 decimal places
cc['No_of_Votes'] = cc['No_of_Votes'].round()
cc
#Alternative approaches:
#1. movies[['Certificate_Category', 'No_of_Votes']].groupby('Certificate_Category').sum().sort_values('No_of_Votes', ascending = False)
#2. movies.groupby('Certificate_Category').agg({'No_of_Votes': 'sum'}).sort_values('No_of_Votes', ascending=False)
# Out:
#                              No_of_Votes
# Certificate_Category
# Parental Guidance Suggested     333794.0
# For Mature Audiences            333559.0
# For General Audiences           222780.0
# Not Available                    59392.0

# %%
cc.reset_index(inplace=True)
# When a pivot table is created or group-by operation is performed, the result often has a new index, such as Certificate_Category.
# This means that Certificate_Category is no longer a regular column but an index of the DataFrame.
# When Seaborn tries to access the column Certificate_Category in the  DataFrame cc, it looks for it among the DataFrame's columns.
# Since Certificate_Category is set as the index instead, it cannot be found in the columns, which leads to the ValueError you encountered.
# Hence, reset_index is required.

# %%
plt.figure(figsize=(15,4))

sns.barplot(data=cc, x='Certificate_Category', y='No_of_Votes')
plt.title('Average Votes by Certificate Category')
# plt.xticks(rotation=45)  - This give TypeError: 'list' object is not callable
# Instead of plt.xticks(), use:
plt.gca().set_xticklabels(plt.gca().get_xticks())
plt.xlabel('Certificate Category')
plt.ylabel('Number of Votes')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Certificate Category vs Gross

# %%
cc2 = movies.pivot_table(index = 'Certificate_Category', values = 'Gross', aggfunc = np.mean).sort_values('Gross', ascending=False)
cc2
# Out:
#                                        Gross
# Certificate_Category
# Parental Guidance Suggested  97255549.375479
# For General Audiences        74397932.158076
# For Mature Audiences         49254170.334294
# Not Available                38713437.069307

# %%
cc2.reset_index(inplace=True)
cc2
# Out:
#           Certificate_Category            Gross
# 0  Parental Guidance Suggested  97255549.375479
# 1        For General Audiences  74397932.158076
# 2         For Mature Audiences  49254170.334294
# 3                Not Available  38713437.069307

# %%
cc2['Gross'] = cc2['Gross'].round()
cc2
# Out:
#           Certificate_Category       Gross
# 0  Parental Guidance Suggested  97255549.0
# 1        For General Audiences  74397932.0
# 2         For Mature Audiences  49254170.0
# 3                Not Available  38713437.0

# %%
plt.figure(figsize=(15,4))

sns.barplot(data=cc2, x='Certificate_Category', y='Gross')
plt.title('Average Gross Earnings by Certificate Category')
# plt.xticks(rotation=45)  - This give TypeError: 'list' object is not callable
# Instead of plt.xticks(), use:
plt.gca().set_xticklabels(plt.gca().get_xticks())
plt.xlabel('Certificate Category')
plt.ylabel('Gross Earnings')
plt.show()

# %%
movies.head(1)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                Series_Title Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption          1994           A      142  Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...          80
#
#          Director        Star1           Star2       Star3           Star4  \
# 0  Frank Darabont  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler
#
#    No_of_Votes     Gross  Certificate_Category
# 0      2343110  28341469  For Mature Audiences

# %% [markdown]
# ---

# %% [markdown]
# ### IMDB_Rating vs Meta_Score
# ### Top Rated movies which are liked by both the movie critics (Metascore) and the general public (IMDB Rating).

# %%
# Set the figure size
plt.figure(figsize=(8, 3))

# Create the scatter plot
sns.scatterplot(data=movies, x='IMDB_Rating', y='Meta_score', color='green')

# Add titles and labels
plt.title('Scatter Plot of IMDB Ratings vs. Meta Score')
plt.xlabel('IMDB Rating')
plt.ylabel('Meta Score')

# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
movies[(movies['IMDB_Rating'] >= 9) & (movies['Meta_score'] >= 80)]['Series_Title']
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### No_of_Votes vs Gross
# #### Are both the columns related to each other?

# %%
# Set the figure size
plt.figure(figsize=(8, 3))

# Create the scatter plot
sns.scatterplot(data=movies, x='No_of_Votes', y='Gross', color='orange')

# Add titles and labels
plt.title('Scatter Plot of No of Votes vs. Gross')
plt.xlabel('No of Votes')
plt.ylabel('Gross')

# Set the limits for the x and y axes to start from 0
plt.xlim(0, movies['No_of_Votes'].max())  # Set x-axis limit from 0 to the max value in No_of_Votes
plt.ylim(0, movies['Gross'].max())  # Set y-axis limit from 0 to the max value in Gross

# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
correlation = movies['No_of_Votes'].corr(movies['Gross'])
print("Correlation coefficient between No_of_Votes and Gross:", correlation)
print("This indicates both are somewhat positively corelated.")
# Out:
# Correlation coefficient between No_of_Votes and Gross: 0.5495816247218166
# This indicates both are somewhat positively corelated.

# %% [markdown]
# #### Director vs IMDB_Rating

# %%
movies.groupby('Director')['IMDB_Rating'].mean().sort_values(ascending = False).head(10)
# movies[movies['Director'],movies['IMDB_Rating'].value_counts() - This won't work as this is a Series method, and not applicable in DataFrames.
# Out:
# Director
# Frank Darabont        8.95
# Irvin Kershner        8.70
# Lana Wachowski        8.70
# George Lucas          8.60
# Roberto Benigni       8.60
# Masaki Kobayashi      8.60
# Thomas Kail           8.60
# Sudha Kongara         8.60
# Fernando Meirelles    8.60
# Roger Allers          8.50
# Name: IMDB_Rating, dtype: float64

# %%
# Step 1: Group by Star1 and calculate average IMDb rating
avg_rating_star1 = movies.groupby('Star1')['IMDB_Rating'].mean().reset_index()
avg_rating_star1.columns = ['Star1', 'Average_IMDB_Rating']

# Step 2: Count the number of movies by each Star1
star1_counts = movies['Star1'].value_counts().reset_index()
star1_counts.columns = ['Star1', 'Number_of_Movies']

# Step 3: Merge the average ratings and counts
stars_summary = avg_rating_star1.merge(star1_counts, on='Star1', how='left')

# Step 4: Filter stars with 3 or more movies
stars_summary_filtered = stars_summary[stars_summary['Number_of_Movies'] >= 3]

# Step 5: Round the average IMDb rating to 1 decimal point
stars_summary_filtered['Average_IMDB_Rating'] = stars_summary_filtered['Average_IMDB_Rating'].round(1)

# Step 6: Sort by average IMDb rating in descending order
stars_summary_sorted = stars_summary_filtered.sort_values(by='Average_IMDB_Rating', ascending=False).head(10)

# Step 7: Display the result
print(stars_summary_sorted)
# Out:
#                Star1  Average_IMDB_Rating  Number_of_Movies
# 184      Elijah Wood                  8.8                 3
# 414      Mark Hamill                  8.5                 3
# 252      Henry Fonda                  8.5                 3
# 111  Charles Chaplin                  8.3                 6
# 591  Tatsuya Nakadai                  8.3                 3
# 358     Kevin Spacey                  8.3                 3
# 0         Aamir Khan                  8.2                 7
# 612   Toshirô Mifune                  8.2                 7
# 273   Jack Nicholson                  8.2                 4
# 282    James Stewart                  8.2                 8

# %% [markdown]
# ### Mulitvariate Analysis
# #### Checking correlation of all the numerical columns in the dataset with each other.
# - IMDB_Rating - No_of_Votes - Gross are all positively corelated to each other.

# %%
numeric_movies = movies.select_dtypes(include='number')
numeric_movies.corr()
# Out:
#               Runtime  IMDB_Rating  Meta_score  No_of_Votes     Gross
# Runtime      1.000000     0.243096   -0.029121     0.173264  0.124626
# IMDB_Rating  0.243096     1.000000    0.249166     0.494979  0.089881
# Meta_score  -0.029121     0.249166    1.000000    -0.009030 -0.026453
# No_of_Votes  0.173264     0.494979   -0.009030     1.000000  0.549582
# Gross        0.124626     0.089881   -0.026453     0.549582  1.000000

# %%
# Plot the heatmap
plt.figure(figsize = (6,3))
sns.heatmap(numeric_movies.corr(), annot=True, cmap="Oranges")
# Show the plot
plt.show()

# %% [markdown]
# #### Plotting pairplot to check all the correlations scatterplot at once for better understanding.

# %%
sns.pairplot(movies)
